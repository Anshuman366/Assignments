# %% [markdown]
# # mysql assignment - 7

# %%
import mysql.connector as conn
mydb=conn.connect(host="localhost",user="root",passwd="anshu@gmail#123")
cursor=mydb.cursor()

import pandas as pd
pd.read_sql("show databases",mydb)
# Out:
#              Database
# 0     carbon_nanotube
# 1          cardataset
# 2            customer
# 3  information_schema
# 4               mysql
# 5                 org
# 6  performance_schema
# 7                 sys
# 8           testanshu

# %%
cursor.execute("use org")

# %%
cursor.execute("show tables")

# %%
cursor.fetchall()
# Out:
# [('bonus',), ('new_customer',), ('title',), ('worker',)]

# %%
pd.read_sql("select * from worker",mydb)
# Out:
#    WORKER_ID FIRST_NAME LAST_NAME  SALARY        JOINING_DATE DEPARTMENT  \
# 0          1     Monika     Arora  100000 2014-02-20 09:00:00         HR
# 1          2   Niharika     Verma   80000 2014-06-11 09:00:00      Admin
# 2          3     Vishal   Singhal  300000 2014-02-20 09:00:00         HR
# 3          4    Amitabh     Singh  500000 2014-02-20 09:00:00      Admin
# 4          5      Vivek     Bhati  500000 2014-06-11 09:00:00      Admin
# 5          6      Vipul     Diwan  200000 2014-06-11 09:00:00    Account
# 6          7     Satish     Kumar   75000 2014-01-20 09:00:00    Account
# 7          8    Geetika   Chauhan   90000 2014-04-11 09:00:00      Admin
#
#          email
# 0  a@gmail.com
# 1  h@gmail.com
# 2  b@gmail.com
# 3  c@gmail.com
# 4  d@gmail.com
# 5  e@gmail.com
# 6   fgmail.com
# 7      g@gmail

# %% [markdown]
# # q1->Write an SQL query to show only odd rows from a table.

# %%
pd.read_sql("select * from worker where WORKER_ID %2!=0",mydb)
# Out:
#    WORKER_ID FIRST_NAME LAST_NAME  SALARY        JOINING_DATE DEPARTMENT  \
# 0          1     Monika     Arora  100000 2014-02-20 09:00:00         HR
# 1          3     Vishal   Singhal  300000 2014-02-20 09:00:00         HR
# 2          5      Vivek     Bhati  500000 2014-06-11 09:00:00      Admin
# 3          7     Satish     Kumar   75000 2014-01-20 09:00:00    Account
#
#          email
# 0  a@gmail.com
# 1  b@gmail.com
# 2  d@gmail.com
# 3   fgmail.com

# %% [markdown]
# # q2-> Write an SQL query to clone a new table from another table.

# %%
pd.read_sql("create table new_customer like worker",mydb)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     522                 query = query.encode('utf-8')
# --> 523             self._cmysql.query(query,
#     524                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Table 'new_customer' already exists
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1724         try:
# -> 1725             cur.execute(*args, **kwargs)
#    1726             return cur
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     268         try:
# ...

# %%
pd.read_sql("select * from new_customer",mydb)
# Out:
#    WORKER_ID FIRST_NAME LAST_NAME  SALARY        JOINING_DATE DEPARTMENT  \
# 0          1     Monika     Arora  100000 2014-02-20 09:00:00         HR
# 1          2   Niharika     Verma   80000 2014-06-11 09:00:00      Admin
# 2          3     Vishal   Singhal  300000 2014-02-20 09:00:00         HR
# 3          4    Amitabh     Singh  500000 2014-02-20 09:00:00      Admin
# 4          5      Vivek     Bhati  500000 2014-06-11 09:00:00      Admin
# 5          6      Vipul     Diwan  200000 2014-06-11 09:00:00    Account
# 6          7     Satish     Kumar   75000 2014-01-20 09:00:00    Account
# 7          8    Geetika   Chauhan   90000 2014-04-11 09:00:00      Admin
#
#          email
# 0  a@gmail.com
# 1  h@gmail.com
# 2  b@gmail.com
# 3  c@gmail.com
# 4  d@gmail.com
# 5  e@gmail.com
# 6   fgmail.com
# 7      g@gmail
